# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %% [markdown]
# ## Retrieving the Nearest City

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 765

# %% [markdown]
# ## Performing an API Call with the OpenWeatherMap

# %%
#Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | codrington
# Processing Record 3 of Set 1 | bucsa
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | melfort
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | khatanga
# Processing Record 8 of Set 1 | hamina
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | phalaborwa
# Processing Record 11 of Set 1 | rocha
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | kodiak
# Processing Record 14 of Set 1 | thompson
# Processing Record 15 of Set 1 | qaqortoq
# Processing Record 16 of Set 1 | bhindar
# Processing Record 17 of Set 1 | ponta do sol
# Processing Record 18 of Set 1 | port elizabeth
# Processing Record 19 of Set 1 | aklavik
# Processing Record 20 of Set 1 | kaitangata
# Processing Record 21 of Set 1 | manzanillo
# Processing Record 22 of Set 1 | ushtobe
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | tuktoyaktuk
# Processing Record 25 of Set 1 | beringovskiy
# Processing Record 26 of Set 1 | sitka
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | kasangulu
# Processing Record 29 of Set 1 | lockhart
# Processing Record 30 of Set 1 | east london
# Processing Record 31 of Set 1 | pevek
# Processing Record 32 of Set 1 | burgeo
# Processing Record 33 of Set 1 | te anau
# Processing Record 34 of Set 1 | pangnirtung
# Processing Record 35 of Set 1 | haines junction
# Processing Record 36 of Set 1 | ondjiva
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | hasaki
# Processing Record 39 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 1 | ashqelon
# Processing Record 42 of Set 1 | churachandpur
# Processing Record 43 of Set 1 | avarua
# Processing Record 44 of Set 1 | dikson
# Processing Record 45 of Set 1 | alofi
# Processing Record 46 of Set 1 | qitaihe
# Processing Record 47 of Set 1 | belleville
# Processing Record 48 of Set 1 | bluff
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | upernavik
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | kapaa
# Processing Record 3 of Set 2 | mahebourg
# Processing Record 4 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 2 | tieling
# Processing Record 6 of Set 2 | hurricane
# Processing Record 7 of Set 2 | ancud
# Processing Record 8 of Set 2 | abu samrah
# Processing Record 9 of Set 2 | saint augustine
# Processing Record 10 of Set 2 | taoudenni
# Processing Record 11 of Set 2 | suao
# City not found. Skipping...
# Processing Record 12 of Set 2 | springdale
# Processing Record 13 of Set 2 | mount isa
# Processing Record 14 of Set 2 | georgetown
# Processing Record 15 of Set 2 | bathsheba
# Processing Record 16 of Set 2 | roald
# Processing Record 17 of Set 2 | marsh harbour
# Processing Record 18 of Set 2 | alyangula
# Processing Record 19 of Set 2 | valle de allende
# Processing Record 20 of Set 2 | zhigalovo
# Processing Record 21 of Set 2 | cidreira
# Processing Record 22 of Set 2 | arraial do cabo
# Processing Record 23 of Set 2 | pacific grove
# Processing Record 24 of Set 2 | clyde river
# Processing Record 25 of Set 2 | sioux lookout
# Processing Record 26 of Set 2 | new norfolk
# Processing Record 27 of Set 2 | gamba
# Processing Record 28 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 29 of Set 2 | balarampur
# Processing Record 30 of Set 2 | geraldton
# Processing Record 31 of Set 2 | caravelas
# Processing Record 32 of Set 2 | mataura
# Processing Record 33 of Set 2 | berdigestyakh
# Processing Record 34 of Set 2 | coahuayana
# Processing Record 35 of Set 2 | port alfred
# Processing Record 36 of Set 2 | dwarka
# Processing Record 37 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 2 | verkhnetulomskiy
# Processing Record 39 of Set 2 | vila franca do campo
# Processing Record 40 of Set 2 | lukulu
# Processing Record 41 of Set 2 | port blair
# Processing Record 42 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 2 | tual
# Processing Record 44 of Set 2 | shingu
# Processing Record 45 of Set 2 | zeya
# Processing Record 46 of Set 2 | hermanus
# Processing Record 47 of Set 2 | carbunari
# Processing Record 48 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 2 | victoria
# Processing Record 50 of Set 2 | san cristobal
# Processing Record 1 of Set 3 | souillac
# Processing Record 2 of Set 3 | rawson
# Processing Record 3 of Set 3 | daru
# Processing Record 4 of Set 3 | iquitos
# Processing Record 5 of Set 3 | zavyalovo
# Processing Record 6 of Set 3 | kavieng
# Processing Record 7 of Set 3 | husavik
# Processing Record 8 of Set 3 | faya
# Processing Record 9 of Set 3 | eyrarbakki
# Processing Record 10 of Set 3 | hithadhoo
# Processing Record 11 of Set 3 | topolobampo
# Processing Record 12 of Set 3 | tura
# Processing Record 13 of Set 3 | henties bay
# Processing Record 14 of Set 3 | brainerd
# Processing Record 15 of Set 3 | lamont
# Processing Record 16 of Set 3 | broken hill
# Processing Record 17 of Set 3 | butaritari
# Processing Record 18 of Set 3 | bethel
# Processing Record 19 of Set 3 | longyearbyen
# Processing Record 20 of Set 3 | rio grande
# Processing Record 21 of Set 3 | sembe
# Processing Record 22 of Set 3 | fairbanks
# Processing Record 23 of Set 3 | estreito
# Processing Record 24 of Set 3 | praya
# Processing Record 25 of Set 3 | birjand
# Processing Record 26 of Set 3 | cordoba
# Processing Record 27 of Set 3 | hobart
# Processing Record 28 of Set 3 | kampot
# Processing Record 29 of Set 3 | constitucion
# Processing Record 30 of Set 3 | severo-kurilsk
# Processing Record 31 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 3 | quatre cocos
# Processing Record 33 of Set 3 | baijiantan
# Processing Record 34 of Set 3 | ribeira grande
# Processing Record 35 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 3 | likasi
# Processing Record 37 of Set 3 | boca do acre
# Processing Record 38 of Set 3 | cabedelo
# Processing Record 39 of Set 3 | richards bay
# Processing Record 40 of Set 3 | verkhnyaya inta
# Processing Record 41 of Set 3 | coihaique
# Processing Record 42 of Set 3 | khasan
# Processing Record 43 of Set 3 | tiksi
# Processing Record 44 of Set 3 | cherskiy
# Processing Record 45 of Set 3 | udachnyy
# Processing Record 46 of Set 3 | kibakwe
# Processing Record 47 of Set 3 | fortuna
# Processing Record 48 of Set 3 | nelson bay
# Processing Record 49 of Set 3 | kenai
# Processing Record 50 of Set 3 | makung
# City not found. Skipping...
# Processing Record 1 of Set 4 | lebu
# Processing Record 2 of Set 4 | anadyr
# Processing Record 3 of Set 4 | estacion coahuila
# Processing Record 4 of Set 4 | villa carlos paz
# Processing Record 5 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 4 | kuldur
# Processing Record 7 of Set 4 | makueni
# Processing Record 8 of Set 4 | touros
# Processing Record 9 of Set 4 | tarakan
# Processing Record 10 of Set 4 | sint michiel
# City not found. Skipping...
# Processing Record 11 of Set 4 | jasper
# Processing Record 12 of Set 4 | jiuquan
# Processing Record 13 of Set 4 | tezu
# Processing Record 14 of Set 4 | port hardy
# Processing Record 15 of Set 4 | iqaluit
# Processing Record 16 of Set 4 | qaanaaq
# Processing Record 17 of Set 4 | flin flon
# Processing Record 18 of Set 4 | mount gambier
# Processing Record 19 of Set 4 | missungwi
# Processing Record 20 of Set 4 | faanui
# Processing Record 21 of Set 4 | hilo
# Processing Record 22 of Set 4 | soligalich
# Processing Record 23 of Set 4 | gualeguay
# Processing Record 24 of Set 4 | petatlan
# Processing Record 25 of Set 4 | zhoucheng
# Processing Record 26 of Set 4 | tocopilla
# Processing Record 27 of Set 4 | provideniya
# Processing Record 28 of Set 4 | assiniboia
# Processing Record 29 of Set 4 | barrow
# Processing Record 30 of Set 4 | hamilton
# Processing Record 31 of Set 4 | craig
# Processing Record 32 of Set 4 | puerto escondido
# Processing Record 33 of Set 4 | tasiilaq
# Processing Record 34 of Set 4 | san quintin
# Processing Record 35 of Set 4 | hoi an
# Processing Record 36 of Set 4 | brasileia
# Processing Record 37 of Set 4 | atuona
# Processing Record 38 of Set 4 | grindavik
# Processing Record 39 of Set 4 | carnarvon
# Processing Record 40 of Set 4 | rudsar
# Processing Record 41 of Set 4 | eldikan
# City not found. Skipping...
# Processing Record 42 of Set 4 | manaure
# Processing Record 43 of Set 4 | vitim
# Processing Record 44 of Set 4 | doha
# Processing Record 45 of Set 4 | bilibino
# Processing Record 46 of Set 4 | castro
# Processing Record 47 of Set 4 | kharp
# Processing Record 48 of Set 4 | warrington
# Processing Record 49 of Set 4 | lagoa
# Processing Record 50 of Set 4 | taganak
# Processing Record 1 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 5 | alice springs
# Processing Record 3 of Set 5 | pisco
# Processing Record 4 of Set 5 | bredasdorp
# Processing Record 5 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 6 of Set 5 | cowra
# Processing Record 7 of Set 5 | paita
# Processing Record 8 of Set 5 | los llanos de aridane
# Processing Record 9 of Set 5 | arman
# Processing Record 10 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 11 of Set 5 | mar del plata
# Processing Record 12 of Set 5 | abu dhabi
# Processing Record 13 of Set 5 | causapscal
# Processing Record 14 of Set 5 | sinnamary
# Processing Record 15 of Set 5 | thinadhoo
# Processing Record 16 of Set 5 | oistins
# Processing Record 17 of Set 5 | galiwinku
# City not found. Skipping...
# Processing Record 18 of Set 5 | nuuk
# Processing Record 19 of Set 5 | wajir
# Processing Record 20 of Set 5 | saint-philippe
# Processing Record 21 of Set 5 | schweinfurt
# Processing Record 22 of Set 5 | arandis
# Processing Record 23 of Set 5 | cruz alta
# Processing Record 24 of Set 5 | porto novo
# Processing Record 25 of Set 5 | sahrak
# City not found. Skipping...
# Processing Record 26 of Set 5 | san andres
# Processing Record 27 of Set 5 | chokurdakh
# Processing Record 28 of Set 5 | sawtell
# Processing Record 29 of Set 5 | sorland
# Processing Record 30 of Set 5 | mahad
# Processing Record 31 of Set 5 | poum
# Processing Record 32 of Set 5 | mahibadhoo
# Processing Record 33 of Set 5 | hami
# Processing Record 34 of Set 5 | tunduru
# City not found. Skipping...
# Processing Record 35 of Set 5 | kruisfontein
# Processing Record 36 of Set 5 | salinas
# Processing Record 37 of Set 5 | kolokani
# Processing Record 38 of Set 5 | toila
# Processing Record 39 of Set 5 | torbay
# Processing Record 40 of Set 5 | sakakah
# Processing Record 41 of Set 5 | soe
# Processing Record 42 of Set 5 | baindur
# Processing Record 43 of Set 5 | buala
# Processing Record 44 of Set 5 | san antonio
# Processing Record 45 of Set 5 | huarmey
# Processing Record 46 of Set 5 | laguna
# Processing Record 47 of Set 5 | sao gabriel da cachoeira
# Processing Record 48 of Set 5 | garmsar
# Processing Record 49 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 50 of Set 5 | ostrovnoy
# Processing Record 1 of Set 6 | willowmore
# Processing Record 2 of Set 6 | atbasar
# Processing Record 3 of Set 6 | vila
# Processing Record 4 of Set 6 | tuatapere
# Processing Record 5 of Set 6 | bosaso
# Processing Record 6 of Set 6 | broome
# Processing Record 7 of Set 6 | srednekolymsk
# Processing Record 8 of Set 6 | zhigansk
# Processing Record 9 of Set 6 | bolshiye uki
# City not found. Skipping...
# Processing Record 10 of Set 6 | mulege
# Processing Record 11 of Set 6 | flagstaff
# Processing Record 12 of Set 6 | solvychegodsk
# Processing Record 13 of Set 6 | mezen
# Processing Record 14 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 15 of Set 6 | sao joao de pirabas
# Processing Record 16 of Set 6 | yulara
# Processing Record 17 of Set 6 | lorengau
# Processing Record 18 of Set 6 | agua verde
# Processing Record 19 of Set 6 | kavaratti
# Processing Record 20 of Set 6 | waipawa
# Processing Record 21 of Set 6 | solnechnyy
# Processing Record 22 of Set 6 | krasnoselkup
# Processing Record 23 of Set 6 | darnah
# Processing Record 24 of Set 6 | zabol
# Processing Record 25 of Set 6 | muhos
# Processing Record 26 of Set 6 | grand-lahou
# Processing Record 27 of Set 6 | mandalgovi
# Processing Record 28 of Set 6 | costa rica
# Processing Record 29 of Set 6 | bisho
# Processing Record 30 of Set 6 | svetlyy
# Processing Record 31 of Set 6 | kamenka
# Processing Record 32 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 6 | ouadda
# Processing Record 34 of Set 6 | bambous virieux
# Processing Record 35 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 36 of Set 6 | bilma
# Processing Record 37 of Set 6 | cody
# Processing Record 38 of Set 6 | sao filipe
# Processing Record 39 of Set 6 | gao
# Processing Record 40 of Set 6 | buhe
# Processing Record 41 of Set 6 | kon tum
# Processing Record 42 of Set 6 | salimbalan
# Processing Record 43 of Set 6 | marystown
# Processing Record 44 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 45 of Set 6 | villazon
# Processing Record 46 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 47 of Set 6 | najibabad
# Processing Record 48 of Set 6 | mandan
# Processing Record 49 of Set 6 | shimoda
# Processing Record 50 of Set 6 | airai
# Processing Record 1 of Set 7 | narsaq
# Processing Record 2 of Set 7 | the valley
# Processing Record 3 of Set 7 | tulun
# Processing Record 4 of Set 7 | nefteyugansk
# Processing Record 5 of Set 7 | capinopolis
# Processing Record 6 of Set 7 | maloshuyka
# City not found. Skipping...
# Processing Record 7 of Set 7 | sisimiut
# Processing Record 8 of Set 7 | vao
# Processing Record 9 of Set 7 | yeppoon
# Processing Record 10 of Set 7 | leningradskiy
# Processing Record 11 of Set 7 | elliot lake
# Processing Record 12 of Set 7 | voyvozh
# Processing Record 13 of Set 7 | hambantota
# Processing Record 14 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 15 of Set 7 | altay
# Processing Record 16 of Set 7 | yomitan
# City not found. Skipping...
# Processing Record 17 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 7 | naze
# Processing Record 19 of Set 7 | brawley
# Processing Record 20 of Set 7 | margate
# Processing Record 21 of Set 7 | douglas
# Processing Record 22 of Set 7 | cockburn town
# Processing Record 23 of Set 7 | tiarei
# Processing Record 24 of Set 7 | dudinka
# Processing Record 25 of Set 7 | taltal
# Processing Record 26 of Set 7 | sar-e pul
# Processing Record 27 of Set 7 | agva
# City not found. Skipping...
# Processing Record 28 of Set 7 | manoel urbano
# Processing Record 29 of Set 7 | sao joao da barra
# Processing Record 30 of Set 7 | palu
# Processing Record 31 of Set 7 | santa isabel do rio negro
# Processing Record 32 of Set 7 | jieshi
# Processing Record 33 of Set 7 | quelimane
# Processing Record 34 of Set 7 | ilebo
# Processing Record 35 of Set 7 | brae
# Processing Record 36 of Set 7 | half moon bay
# Processing Record 37 of Set 7 | vrede
# Processing Record 38 of Set 7 | nishihara
# Processing Record 39 of Set 7 | nagornskiy
# Processing Record 40 of Set 7 | naryan-mar
# Processing Record 41 of Set 7 | ratnagiri
# Processing Record 42 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 7 | alamos
# Processing Record 44 of Set 7 | dolores
# Processing Record 45 of Set 7 | shubarkuduk
# Processing Record 46 of Set 7 | asau
# Processing Record 47 of Set 7 | tazovskiy
# Processing Record 48 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 7 | tineo
# Processing Record 50 of Set 7 | niort
# Processing Record 1 of Set 8 | kashi
# Processing Record 2 of Set 8 | nikolskoye
# Processing Record 3 of Set 8 | ukiah
# Processing Record 4 of Set 8 | boyolangu
# Processing Record 5 of Set 8 | bubaque
# Processing Record 6 of Set 8 | antalaha
# Processing Record 7 of Set 8 | havelock
# Processing Record 8 of Set 8 | wamba
# Processing Record 9 of Set 8 | chapais
# Processing Record 10 of Set 8 | cap malheureux
# Processing Record 11 of Set 8 | nogales
# Processing Record 12 of Set 8 | guryevsk
# Processing Record 13 of Set 8 | capinota
# Processing Record 14 of Set 8 | katsuura
# Processing Record 15 of Set 8 | verkhnevilyuysk
# Processing Record 16 of Set 8 | novyy urengoy
# Processing Record 17 of Set 8 | sant
# Processing Record 18 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 8 | taonan
# Processing Record 20 of Set 8 | rapid valley
# Processing Record 21 of Set 8 | muros
# Processing Record 22 of Set 8 | vestmannaeyjar
# Processing Record 23 of Set 8 | ozernovskiy
# Processing Record 24 of Set 8 | nemuro
# Processing Record 25 of Set 8 | palmer
# Processing Record 26 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 8 | thunder bay
# Processing Record 28 of Set 8 | xuddur
# Processing Record 29 of Set 8 | ust-kalmanka
# Processing Record 30 of Set 8 | santa branca
# Processing Record 31 of Set 8 | banda aceh
# Processing Record 32 of Set 8 | cedar city
# Processing Record 33 of Set 8 | ahipara
# Processing Record 34 of Set 8 | wanning
# Processing Record 35 of Set 8 | kastamonu
# Processing Record 36 of Set 8 | saint-joseph
# Processing Record 37 of Set 8 | meulaboh
# Processing Record 38 of Set 8 | olga
# Processing Record 39 of Set 8 | palana
# Processing Record 40 of Set 8 | portobelo
# Processing Record 41 of Set 8 | antofagasta
# Processing Record 42 of Set 8 | lompoc
# Processing Record 43 of Set 8 | lazurne
# Processing Record 44 of Set 8 | stryn
# Processing Record 45 of Set 8 | khorixas
# Processing Record 46 of Set 8 | kawalu
# Processing Record 47 of Set 8 | harper
# Processing Record 48 of Set 8 | anstruther
# Processing Record 49 of Set 8 | miri
# Processing Record 50 of Set 8 | kousseri
# Processing Record 1 of Set 9 | seydi
# Processing Record 2 of Set 9 | mogadishu
# Processing Record 3 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 9 | sena madureira
# Processing Record 5 of Set 9 | kuandian
# Processing Record 6 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 7 of Set 9 | krasnokamensk
# Processing Record 8 of Set 9 | shenjiamen
# Processing Record 9 of Set 9 | kosh-agach
# Processing Record 10 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 11 of Set 9 | ilulissat
# Processing Record 12 of Set 9 | champerico
# Processing Record 13 of Set 9 | yar-sale
# Processing Record 14 of Set 9 | iskateley
# Processing Record 15 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 16 of Set 9 | vallam
# Processing Record 17 of Set 9 | nago
# Processing Record 18 of Set 9 | clovis
# Processing Record 19 of Set 9 | akureyri
# Processing Record 20 of Set 9 | pingliang
# Processing Record 21 of Set 9 | emerald
# Processing Record 22 of Set 9 | sayanskiy
# City not found. Skipping...
# Processing Record 23 of Set 9 | surt
# Processing Record 24 of Set 9 | isangel
# Processing Record 25 of Set 9 | walvis bay
# Processing Record 26 of Set 9 | kamina
# Processing Record 27 of Set 9 | san rafael
# Processing Record 28 of Set 9 | ebeltoft
# Processing Record 29 of Set 9 | alanya
# Processing Record 30 of Set 9 | awka
# Processing Record 31 of Set 9 | chernyshevskiy
# Processing Record 32 of Set 9 | carauari
# Processing Record 33 of Set 9 | namatanai
# Processing Record 34 of Set 9 | dunedin
# Processing Record 35 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 36 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 9 | alexandria
# Processing Record 38 of Set 9 | san policarpo
# Processing Record 39 of Set 9 | lianzhou
# Processing Record 40 of Set 9 | inta
# Processing Record 41 of Set 9 | marawi
# Processing Record 42 of Set 9 | bengkulu
# Processing Record 43 of Set 9 | raudeberg
# Processing Record 44 of Set 9 | luneville
# Processing Record 45 of Set 9 | boguchany
# Processing Record 46 of Set 9 | kununurra
# Processing Record 47 of Set 9 | anloga
# Processing Record 48 of Set 9 | bolshoye murashkino
# Processing Record 49 of Set 9 | sivas
# Processing Record 50 of Set 9 | esperance
# Processing Record 1 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 10 | baykit
# Processing Record 3 of Set 10 | malihabad
# Processing Record 4 of Set 10 | saint george
# Processing Record 5 of Set 10 | coquimbo
# Processing Record 6 of Set 10 | mildura
# Processing Record 7 of Set 10 | chitral
# Processing Record 8 of Set 10 | kutulik
# Processing Record 9 of Set 10 | puerto cortes
# City not found. Skipping...
# Processing Record 10 of Set 10 | troitsko-pechorsk
# Processing Record 11 of Set 10 | sibolga
# Processing Record 12 of Set 10 | salalah
# Processing Record 13 of Set 10 | chuy
# Processing Record 14 of Set 10 | college
# Processing Record 15 of Set 10 | hualmay
# Processing Record 16 of Set 10 | san pedro
# Processing Record 17 of Set 10 | kishtwar
# Processing Record 18 of Set 10 | saskylakh
# Processing Record 19 of Set 10 | yenagoa
# Processing Record 20 of Set 10 | marzuq
# Processing Record 21 of Set 10 | am timan
# Processing Record 22 of Set 10 | komsomolskiy
# Processing Record 23 of Set 10 | requena
# Processing Record 24 of Set 10 | linping
# Processing Record 25 of Set 10 | almeirim
# Processing Record 26 of Set 10 | naftah
# City not found. Skipping...
# Processing Record 27 of Set 10 | port macquarie
# Processing Record 28 of Set 10 | vitimskiy
# City not found. Skipping...
# Processing Record 29 of Set 10 | tuytepa
# Processing Record 30 of Set 10 | vysokogornyy
# Processing Record 31 of Set 10 | sabang
# Processing Record 32 of Set 10 | cassilandia
# Processing Record 33 of Set 10 | san julian
# Processing Record 34 of Set 10 | beloha
# Processing Record 35 of Set 10 | rosetta
# Processing Record 36 of Set 10 | aripuana
# Processing Record 37 of Set 10 | kahului
# Processing Record 38 of Set 10 | omboue
# Processing Record 39 of Set 10 | vardo
# Processing Record 40 of Set 10 | elk river
# Processing Record 41 of Set 10 | pokrovsk
# Processing Record 42 of Set 10 | fatehabad
# Processing Record 43 of Set 10 | sheksna
# Processing Record 44 of Set 10 | mehamn
# Processing Record 45 of Set 10 | kendari
# Processing Record 46 of Set 10 | rio gallegos
# Processing Record 47 of Set 10 | halifax
# Processing Record 48 of Set 10 | erzurum
# Processing Record 49 of Set 10 | labuhan
# Processing Record 50 of Set 10 | itarantim
# Processing Record 1 of Set 11 | mao
# Processing Record 2 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 11 | alta floresta
# Processing Record 4 of Set 11 | vanimo
# Processing Record 5 of Set 11 | pushchino
# Processing Record 6 of Set 11 | kollumerland
# City not found. Skipping...
# Processing Record 7 of Set 11 | cilegon
# Processing Record 8 of Set 11 | matsanga
# City not found. Skipping...
# Processing Record 9 of Set 11 | comodoro rivadavia
# Processing Record 10 of Set 11 | tataranu
# Processing Record 11 of Set 11 | camacupa
# Processing Record 12 of Set 11 | egvekinot
# Processing Record 13 of Set 11 | knokke-heist
# Processing Record 14 of Set 11 | luderitz
# Processing Record 15 of Set 11 | minsk mazowiecki
# Processing Record 16 of Set 11 | gidam
# Processing Record 17 of Set 11 | talnakh
# Processing Record 18 of Set 11 | garowe
# Processing Record 19 of Set 11 | kayes
# Processing Record 20 of Set 11 | high prairie
# Processing Record 21 of Set 11 | emiliano zapata
# Processing Record 22 of Set 11 | guerrero negro
# Processing Record 23 of Set 11 | araouane
# Processing Record 24 of Set 11 | hobyo
# Processing Record 25 of Set 11 | russkaya polyana
# Processing Record 26 of Set 11 | nova friburgo
# Processing Record 27 of Set 11 | praia da vitoria
# Processing Record 28 of Set 11 | impfondo
# Processing Record 29 of Set 11 | kigali
# Processing Record 30 of Set 11 | san isidro
# Processing Record 31 of Set 11 | votkinsk
# Processing Record 32 of Set 11 | berwick
# Processing Record 33 of Set 11 | vinh
# Processing Record 34 of Set 11 | norman wells
# Processing Record 35 of Set 11 | gat
# Processing Record 36 of Set 11 | morehead
# Processing Record 37 of Set 11 | matagami
# Processing Record 38 of Set 11 | san juan
# Processing Record 39 of Set 11 | dingle
# Processing Record 40 of Set 11 | vieques
# Processing Record 41 of Set 11 | mikuni
# Processing Record 42 of Set 11 | saint anthony
# Processing Record 43 of Set 11 | formosa do rio preto
# Processing Record 44 of Set 11 | port lincoln
# Processing Record 45 of Set 11 | sebring
# Processing Record 46 of Set 11 | thung song
# Processing Record 47 of Set 11 | carutapera
# Processing Record 48 of Set 11 | teya
# Processing Record 49 of Set 11 | cristalina
# Processing Record 50 of Set 11 | saint-francois
# Processing Record 1 of Set 12 | lampang
# Processing Record 2 of Set 12 | rusape
# Processing Record 3 of Set 12 | mago
# Processing Record 4 of Set 12 | lavrentiya
# Processing Record 5 of Set 12 | ucluelet
# Processing Record 6 of Set 12 | camacha
# Processing Record 7 of Set 12 | vestmanna
# Processing Record 8 of Set 12 | mayo
# Processing Record 9 of Set 12 | kurtalan
# Processing Record 10 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 11 of Set 12 | moron
# Processing Record 12 of Set 12 | morondava
# Processing Record 13 of Set 12 | bontang
# Processing Record 14 of Set 12 | anapskaya
# Processing Record 15 of Set 12 | qianan
# Processing Record 16 of Set 12 | san mateo
# Processing Record 17 of Set 12 | paamiut
# Processing Record 18 of Set 12 | cajati
# Processing Record 19 of Set 12 | pozo colorado
# Processing Record 20 of Set 12 | tabas
# Processing Record 21 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 22 of Set 12 | mumbwa
# Processing Record 23 of Set 12 | tilichiki
# Processing Record 24 of Set 12 | batagay-alyta
# Processing Record 25 of Set 12 | visnes
# Processing Record 26 of Set 12 | along
# Processing Record 27 of Set 12 | tete
# Processing Record 28 of Set 12 | langub
# Processing Record 29 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 30 of Set 12 | aswan
# Processing Record 31 of Set 12 | nouadhibou
# Processing Record 32 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 12 | kozhva
# Processing Record 34 of Set 12 | lazaro cardenas
# Processing Record 35 of Set 12 | leh
# Processing Record 36 of Set 12 | kamaishi
# Processing Record 37 of Set 12 | nanortalik
# Processing Record 38 of Set 12 | sartell
# Processing Record 39 of Set 12 | road town
# Processing Record 40 of Set 12 | saldanha
# Processing Record 41 of Set 12 | minab
# Processing Record 42 of Set 12 | miramar
# Processing Record 43 of Set 12 | puerto del rosario
# Processing Record 44 of Set 12 | bafra
# Processing Record 45 of Set 12 | srandakan
# Processing Record 46 of Set 12 | marabba
# Processing Record 47 of Set 12 | barda
# Processing Record 48 of Set 12 | juegang
# Processing Record 49 of Set 12 | baiyin
# Processing Record 50 of Set 12 | ketchikan
# Processing Record 1 of Set 13 | vila velha
# Processing Record 2 of Set 13 | marang
# Processing Record 3 of Set 13 | san ramon de la nueva oran
# Processing Record 4 of Set 13 | voh
# Processing Record 5 of Set 13 | nanakuli
# Processing Record 6 of Set 13 | jerome
# Processing Record 7 of Set 13 | manokwari
# Processing Record 8 of Set 13 | nizwa
# Processing Record 9 of Set 13 | riyadh
# Processing Record 10 of Set 13 | cabo san lucas
# Processing Record 11 of Set 13 | ostersund
# Processing Record 12 of Set 13 | acala
# Processing Record 13 of Set 13 | orlik
# Processing Record 14 of Set 13 | conakry
# Processing Record 15 of Set 13 | igarka
# Processing Record 16 of Set 13 | zverinogolovskoye
# Processing Record 17 of Set 13 | makhachkala
# Processing Record 18 of Set 13 | hofn
# Processing Record 19 of Set 13 | asosa
# Processing Record 20 of Set 13 | marhaura
# Processing Record 21 of Set 13 | deputatskiy
# Processing Record 22 of Set 13 | ust-kuyga
# Processing Record 23 of Set 13 | severodvinsk
# Processing Record 24 of Set 13 | malanje
# Processing Record 25 of Set 13 | gejiu
# Processing Record 26 of Set 13 | sokoni
# Processing Record 27 of Set 13 | snyder
# Processing Record 28 of Set 13 | san patricio
# Processing Record 29 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 30 of Set 13 | taksimo
# Processing Record 31 of Set 13 | taseyevo
# Processing Record 32 of Set 13 | anar darreh
# City not found. Skipping...
# Processing Record 33 of Set 13 | banjar
# Processing Record 34 of Set 13 | moranbah
# Processing Record 35 of Set 13 | mount pleasant
# Processing Record 36 of Set 13 | kathmandu
# Processing Record 37 of Set 13 | muravlenko
# Processing Record 38 of Set 13 | moroni
# Processing Record 39 of Set 13 | byron bay
# Processing Record 40 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 41 of Set 13 | athmallik
# Processing Record 42 of Set 13 | gampengrejo
# Processing Record 43 of Set 13 | hovd
# Processing Record 44 of Set 13 | vammala
# Processing Record 45 of Set 13 | limbang
# Processing Record 46 of Set 13 | hargeysa
# Processing Record 47 of Set 13 | maldonado
# Processing Record 48 of Set 13 | zinder
# Processing Record 49 of Set 13 | ponta delgada
# Processing Record 50 of Set 13 | tempio pausania
# Processing Record 1 of Set 14 | urengoy
# Processing Record 2 of Set 14 | dubbo
# Processing Record 3 of Set 14 | san juan del sur
# Processing Record 4 of Set 14 | kharabali
# Processing Record 5 of Set 14 | mbandaka
# Processing Record 6 of Set 14 | fairview
# Processing Record 7 of Set 14 | kudahuvadhoo
# Processing Record 8 of Set 14 | galle
# Processing Record 9 of Set 14 | channahon
# Processing Record 10 of Set 14 | lasa
# Processing Record 11 of Set 14 | skibbereen
# Processing Record 12 of Set 14 | korla
# Processing Record 13 of Set 14 | maraa
# Processing Record 14 of Set 14 | goundam
# Processing Record 15 of Set 14 | galich
# Processing Record 16 of Set 14 | westport
# Processing Record 17 of Set 14 | ulladulla
# Processing Record 18 of Set 14 | kondinskoye
# Processing Record 19 of Set 14 | plouzane
# Processing Record 20 of Set 14 | mangan
# Processing Record 21 of Set 14 | chuguyevka
# Processing Record 22 of Set 14 | bandarbeyla
# Processing Record 23 of Set 14 | karratha
# Processing Record 24 of Set 14 | roebourne
# Processing Record 25 of Set 14 | vetrni
# Processing Record 26 of Set 14 | sabha
# Processing Record 27 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 14 | nanchang
# Processing Record 29 of Set 14 | chara
# Processing Record 30 of Set 14 | bud
# Processing Record 31 of Set 14 | shchelyayur
# City not found. Skipping...
# Processing Record 32 of Set 14 | amurrio
# Processing Record 33 of Set 14 | megion
# Processing Record 34 of Set 14 | ust-kut
# Processing Record 35 of Set 14 | puquio
# Processing Record 36 of Set 14 | namie
# Processing Record 37 of Set 14 | chipinge
# Processing Record 38 of Set 14 | griffith
# Processing Record 39 of Set 14 | el astillero
# Processing Record 40 of Set 14 | chenzhou
# Processing Record 41 of Set 14 | kem
# Processing Record 42 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 43 of Set 14 | amahai
# Processing Record 44 of Set 14 | puerto ayacucho
# Processing Record 45 of Set 14 | amapa
# Processing Record 46 of Set 14 | beyla
# Processing Record 47 of Set 14 | artyom
# Processing Record 48 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 49 of Set 14 | xai-xai
# Processing Record 50 of Set 14 | dondo
# Processing Record 1 of Set 15 | treinta y tres
# Processing Record 2 of Set 15 | adrar
# Processing Record 3 of Set 15 | ranot
# Processing Record 4 of Set 15 | cururupu
# Processing Record 5 of Set 15 | marathon
# Processing Record 6 of Set 15 | caxito
# Processing Record 7 of Set 15 | zwedru
# Processing Record 8 of Set 15 | myitkyina
# Processing Record 9 of Set 15 | acapulco
# Processing Record 10 of Set 15 | labuan
# Processing Record 11 of Set 15 | icatu
# Processing Record 12 of Set 15 | niksic
# Processing Record 13 of Set 15 | kropotkin
# Processing Record 14 of Set 15 | viedma
# Processing Record 15 of Set 15 | sao paulo de olivenca
# Processing Record 16 of Set 15 | beyneu
# Processing Record 17 of Set 15 | fuerte olimpo
# Processing Record 18 of Set 15 | key west
# Processing Record 19 of Set 15 | sola
# Processing Record 20 of Set 15 | lixourion
# Processing Record 21 of Set 15 | san carlos de bariloche
# Processing Record 22 of Set 15 | normandin
# Processing Record 23 of Set 15 | buqayq
# City not found. Skipping...
# Processing Record 24 of Set 15 | puerto baquerizo moreno
# Processing Record 25 of Set 15 | biak
# Processing Record 26 of Set 15 | kyzyl-suu
# Processing Record 27 of Set 15 | ayan
# Processing Record 28 of Set 15 | anderson
# Processing Record 29 of Set 15 | naifaru
# Processing Record 30 of Set 15 | aksu
# Processing Record 31 of Set 15 | miraflores
# Processing Record 32 of Set 15 | cervo
# Processing Record 33 of Set 15 | kyabe
# Processing Record 34 of Set 15 | kalmunai
# Processing Record 35 of Set 15 | lubango
# Processing Record 36 of Set 15 | hervey bay
# Processing Record 37 of Set 15 | lebyazhye
# Processing Record 38 of Set 15 | imeni lva tolstogo
# City not found. Skipping...
# Processing Record 39 of Set 15 | longhua
# Processing Record 40 of Set 15 | namibe
# Processing Record 41 of Set 15 | kalevala
# Processing Record 42 of Set 15 | el coco
# Processing Record 43 of Set 15 | kaolinovo
# Processing Record 44 of Set 15 | ankang
# Processing Record 45 of Set 15 | muisne
# Processing Record 46 of Set 15 | sigli
# Processing Record 47 of Set 15 | atambua
# Processing Record 48 of Set 15 | havoysund
# Processing Record 49 of Set 15 | grand forks
# Processing Record 50 of Set 15 | le francois
# Processing Record 1 of Set 16 | tungor
# Processing Record 2 of Set 16 | sironj
# Processing Record 3 of Set 16 | kuusamo
# Processing Record 4 of Set 16 | sakaiminato
# Processing Record 5 of Set 16 | olafsvik
# Processing Record 6 of Set 16 | affery
# Processing Record 7 of Set 16 | kouango
# Processing Record 8 of Set 16 | norsup
# Processing Record 9 of Set 16 | batouri
# Processing Record 10 of Set 16 | carballo
# Processing Record 11 of Set 16 | mutoko
# Processing Record 12 of Set 16 | sungairaya
# Processing Record 13 of Set 16 | atlantis
# Processing Record 14 of Set 16 | puerto madero
# Processing Record 15 of Set 16 | kimbe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 702

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0  Yellowknife      CA  62.46 -114.35     15.80        85          90
# 1   Codrington      AU -38.27  141.97     71.31        57           0
# 2        Bucsa      HU  47.20   21.00     36.00       100          90
# 3       Albany      US  42.60  -73.97     36.00        60          61
# 4      Melfort      CA  52.87 -104.62     21.20        85          97
# 5    Cape Town      ZA -33.93   18.42     59.00        58          75
# 6     Khatanga      RU  71.97  102.50      8.89        96         100
# 7       Hamina      FI  60.57   27.20     30.20        92          90
# 8      Rikitea      PF -23.12 -134.97     74.82        83          98
# 9   Phalaborwa      ZA -23.94   31.14     80.60        65          41
#
#    Wind Speed Current Description
# 0       10.29          light snow
# 1       11.74           clear sky
# 2        3.36                mist
# 3        3.47       broken clouds
# 4        8.05     overcast clouds
# 5        5.82       broken clouds
# 6        7.14     overcast clouds
# 7        3.36     overcast clouds
# 8       11.99          light rain
# 9        2.24    scattered clouds

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
